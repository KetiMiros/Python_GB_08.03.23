# %% [markdown]
# <a href="https://colab.research.google.com/github/KetiMiros/Python_GB_08.03.23/blob/lesson9/Lesson9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df[(df['population'] > 500) ]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# 5        -114.58     33.63                29.0       1387.0           236.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
print(df['median_house_value'].max())
print(df['median_house_value'].min())
print(df['median_house_value'].mean())
print(df['median_house_value'].median())
# Out:
# 500001.0
# 14999.0
# 207300.91235294117
# 180400.0

# %%
df['median_house_value'].max(), df['median_house_value'].min(), df['median_house_value'].mean().round(2), df['median_house_value'].median()
# Out:
# (500001.0, 14999.0, 207300.91, 180400.0)

# %%
import seaborn as sns
sns.scatterplot(data=df, y="population", x="housing_median_age", hue="median_house_value")
sns.relplot(x="population", y="median_house_value", kind="line", data=df)

# %%
sns.relplot(x = 'population', y = 'median_house_value', kind = 'line', data = df)

# %%
sns.histplot(data=df, x="median_house_value")
#Столбчатая диаграмма. 
#По оси x указано значение, а по оси y - встречаемость(кол-во таких значений в выборке).
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>

# %%
df.loc[df['population'] <= 500, 'pop_group'] = 'Жителей до 500' #создание группы до 500 жителей
df.groupby('pop_group')['median_house_value'].min().plot(kind='bar') # минимальная значение median_house_value в зоне до 500 чел.
# Out:
# <Axes: xlabel='pop_group'>

# %%
#максимальное значение median_house_value в зоне до 500 чел.
df.groupby('pop_group')['median_house_value'].max().plot(kind='bar')
# Out:
# <Axes: xlabel='pop_group'>

# %%
df.groupby('pop_group')['median_house_value'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='pop_group'>

# %%
df.groupby('pop_group')['median_house_value'].median().plot(kind='bar') # среднее значение median_house_value в зоне до 500 чел.
# Out:
# <Axes: xlabel='pop_group'>

# %%
df['population'].min()
# Out:
# 3.0

# %%
df['households'].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0        472.0
# 1        463.0
# 2        117.0
# 3        226.0
# 4        262.0
#          ...
# 16995    369.0
# 16996    465.0
# 16997    456.0
# 16998    478.0
# 16999    270.0
# Name: households, Length: 17000, dtype: float64>

# %%
df.loc[df['population'].min(), 'min_group'] = 'Минимум жителей' #создание группы минимальной по жителям

# %%
df.groupby('min_group')['households'].max().plot(kind='bar') #максимальное значение households в зоне наименьшей популяции
# Out:
# <Axes: xlabel='min_group'>
